# %% [markdown]
# ---
# # *Multi-criteria decision making (MCDM) using Topsis*
# ---

# %%
# 1.1 Installing topsis pelo terminal
#pip install pymcdm

# %%
# 1.2 Imports
import pandas as pd
import numpy as np
from pymcdm.methods import TOPSIS
from pymcdm.normalizations import vector_normalization

# %%
# 1.3 Read the dataset
mydata = pd.read_csv('TOPSIS_project.csv', sep=';', skip_blank_lines=True)
#mydata = mydata.dropna()  # Remove linhas com missing values
mydata
# Out:
# Empty DataFrame
# Columns: [Donor_id, HLA Match, CMV Serostatus	, Donor Age Group, Gender Match, ABO Match, Expected Survival Time, Unnamed: 7, Unnamed: 8]
# Index: []

# %%
# 1.4 Convert the dataset to Matrix
# Drop the first column and convert to NumPy array
d = mydata.iloc[:, 1:].values.astype(int)
d
# Out:
# array([], shape=(0, 8), dtype=int64)

# %%
# 1.5 Assigning the impacts
# 1 for maximization and -1 for minimization
# Maximize: HLA_match, donor_age_group, ABO_match, expected_time_survival
# Minimize: CMV_status, Gender_match

i = np.array([1, -1, 1, -1, 1, 1], dtype=int)
i
# Out:
# array([ 1, -1,  1, -1,  1,  1])

# %%
# 1.6 Assigning the weights
# Os pesos das variáveis foram definidos com base num modelo de decaimento exponencial, de forma a refletir a hierarquia clínica de importância entre os parâmetros. O peso bruto da variável na posição i foi calculado como wi​=α^(i−1) sendo i=1 a variável mais relevante. Considerando que o parâmetro HLA_match é crítico, o fator de decaimento foi fixado em α=0.5, garantindo que este concentra a maior parte da importância total.
# Os pesos brutos obtidos [1,0.5,0.25,0.125,0.0625,0.03125] foram posteriormente normalizados por divisão pela sua soma (S=1,96875), assegurando que todos os pesos finais se encontram no intervalo [0,1] e que a soma total é unitária. Após normalização, obtiveram-se os pesos finais [0.5080,0.2540,0.1270,0.0635,0.0317,0.0159].

# HLA_match=
# CMV_status=
# donor_age_group=
# Gender_match=
# ABO_match=
# expected_time_survival=

# α=0.6
#w = np.array([0.4196, 0.2518, 0.1510, 0.0906, 0.0544, 0.0326], dtype=float)

# α=0.55
#w = np.array([0.463,0.255,0.140,0.077,0.042,0.023], dtype=float)

# α=0.5
w = np.array([0.5080, 0.2540, 0.1270, 0.0635, 0.0317, 0.0159], dtype=float)
w
# Out:
# array([0.508 , 0.254 , 0.127 , 0.0635, 0.0317, 0.0159])

# %%
# 1.7 Calling the topsis function
# scores = topsis(
#     data,        # matriz de decisão (alternativas × critérios)
#     weights,     # pesos dos critérios
#     impacts      # impactos: '1' ou '-1'
# )

topsis = TOPSIS(normalization_function=vector_normalization)
resultados = topsis(d, w, i)
resultados
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 9
#       1 # 1.7 Calling the topsis function
#       2 # scores = topsis(
#       3 #     data,        # matriz de decisão (alternativas × critérios)
#       4 #     weights,     # pesos dos critérios
#       5 #     impacts      # impactos: '1' ou '-1'
#       6 # )
#       8 topsis = TOPSIS(normalization_function=vector_normalization)
# ----> 9 resultados = topsis(d, w, i)
#      10 resultados
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymcdm\methods\mcda_method.py:51, in MCDA_method.__call__(self, matrix, weights, types, validation, verbose)
#      48 types = np.asarray(types)
#      50 if validation:
# ---> 51     validate_decision_problem(matrix, weights, types)
#      52     self._additional_validation(matrix, weights, types)
#      54 if verbose:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymcdm\validators.py:685, in validate_decision_problem(matrix, weights, types)
#     636 def validate_decision_problem(matrix: np.ndarray, weights: np.ndarray, types: np.ndarray):
#     637     """
#     638     Validates the components of a decision problem, including the decision matrix, weights, and types.
#     639
#    (...)    683     UserWarning: Weights should be positive and its sum should be equal one. Now, sum of the weights is 0.9.
#     684     """
# --> 685     matrix_validator(matrix, types)
#     686     weights_validator(matrix, weights)
#     687     types_validator(matrix, types)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymcdm\validators.py:510, in matrix_validator(matrix, types)
#     455 """
#     456 Validates the decision matrix and checks for dominant or dominated alternatives.
#     457
#    (...)    506 as such alternatives can cause numerical errors in some methods.
#     507 """
#     508 array_dimension_validator(matrix, 2, 'Matrix')
# --> 510 max_alt = np.max(matrix, axis=0)
#     511 min_alt = np.min(matrix, axis=0)
#     513 dominant = [max_alt[i] if types[i] == 1 else min_alt[i]
#     514             for i in range(matrix.shape[1])]
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:3164, in max(a, axis, out, keepdims, initial, where)
#    3052 @array_function_dispatch(_max_dispatcher)
#    3053 @set_module('numpy')
#    3054 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    3055          where=np._NoValue):
#    3056     """
#    3057     Return the maximum of an array or maximum along an axis.
#    3058
#    (...)   3162     5
#    3163     """
# -> 3164     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    3165                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
#1.8 Cria tabela final

# Get the first column
primeira_coluna = mydata.iloc[:, 0]  # Keep as Series

# Convert results to Series
resultados_series = pd.Series(resultados, name='TOPSIS Score')

# Concatenate along columns
df = pd.concat([primeira_coluna, resultados_series], axis=1)
print(df)

# Sort by TOPSIS_Score in descending order (highest to lowest)
df = df.sort_values(by='TOPSIS Score', ascending=False)
df.rename(columns={'TOPSIS Score': 'TOPSIS Rank'}, inplace=True)
df
