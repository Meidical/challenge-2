# %% [markdown]
# # Ficheiro para ler csv de forma a testar o TOPSIS, pois a classe TOPSIS irá receber um dataframe.

# %%
import pandas as pd

# Read the dataset
mydata = pd.read_csv('TOPSIS_project.csv', sep=';', skip_blank_lines=True)
#mydata = mydata.dropna()  # Remove linhas com missing values
mydata

# Drop the first column and convert to NumPy array
mydata_no_first_column = mydata.iloc[:, 1:].values.astype(int)
mydata_no_first_column
