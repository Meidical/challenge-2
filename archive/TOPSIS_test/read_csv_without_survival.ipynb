# %% [markdown]
# Ficheiro para ler csv de forma a testar o TOPSIS, pois a classe TOPSIS irá receber um dataframe.

# %%
import pandas as pd

# Read the dataset
mydata = pd.read_csv('TOPSIS_project_without_survival.csv', sep=';', skip_blank_lines=True)
mydata['Donor_id'] = mydata['Donor_id'].astype('string')
mydata
# Out:
#    Donor_id  HLA Match  CMV Serostatus\t  Donor Age Group  Gender Match  \
# 0     IDO01          7                 0                0             0
# 1     IDO02          8                 1                1             1
# 2     IDO03          9                 2                2             0
# 3     IDO04          7                 3                0             1
# 4     IDO05         10                 0                2             0
# 5     IDO06         10                 3                0             1
# 6     IDO07          8                 0                1             1
# 7     IDO08          9                 1                0             0
# 8     IDO09          7                 2                2             1
# 9     IDO10         10                 0                1             0
# 10    IDO11          9                 3                0             1
# 11    IDO12          8                 1                2             0
# ...
